# %%
# !pip install geopy
import pandas as pd
import math

column_names = [
    "url",          # 0: https://...
    "title",        # 1: Vente Maison...
    "location",     # 2: Bray sur seine...
    "desc_short",   # 3: Description T4...
    "description",  # 4: À Vendre...
    "rooms",        # 5: 4
    "surface",      # 6: 92
    "price",        # 7: 139 750
    "agency",       # 8: L'ADRESSE CHESSY
    "agencement",   # 9: 3 chambres, 1 salle de bain
    "general",    # 10: (vide dans ton exemple)
    "annexes",      # 11: Cave
    "dependence",      # 12: Terrasse
    "id_tech",      # 13: 1764140340
    "reference"     # 14: ParuVendu...
]

# On charge tout en 'string' (dtype=str) pour éviter les erreurs de conversion au début
try:
    df = pd.read_csv(
        "data/results.csv",
        header=None,
        names=column_names,
        dtype=str,
        on_bad_lines='skip' # Si une ligne est mal formée, on la saute au lieu de planter
    )
except Exception as e:
    print(f"Erreur à l'ouverture du fichier : {e}")
    df = pd.DataFrame()

df.head()  # Affiche les premières lignes du DataFrame pour vérification²
# Out:
# Requirement already satisfied: geopy in /opt/anaconda3/lib/python3.13/site-packages (2.4.1)
# Requirement already satisfied: geographiclib<3,>=1.52 in /opt/anaconda3/lib/python3.13/site-packages (from geopy) (2.1)
#                                                  url  \
# 0  https://www.paruvendu.fr/immobilier/vente/mais...
# 1  https://www.paruvendu.fr/immobilier/vente/mais...
# 2  https://www.paruvendu.fr/immobilier/vente/mais...
# 3  https://www.paruvendu.fr/immobilier/vente/appa...
# 4  https://www.paruvendu.fr/immobilier/vente/mais...
#
#                               title                    location  \
# 0       Vente Maison 4 pièces 92 m²      Bray sur seine (77480)
# 1      Vente Maison 5 pièces 132 m²             Provins (77160)
# 2      Vente Maison 7 pièces 150 m²               Orsay (91400)
# 3  Vente Appartement 3 pièces 56 m²    Le mee-sur-seine (77350)
# 4      Vente Maison 6 pièces 110 m²  La grande-paroisse (77130)
#
#                             desc_short  \
# 0      Description T4 à Bray sur seine
# 1             Description T5 à Provins
# 2               Description T7 à Orsay
# 3    Description T3 à Le mee-sur-seine
# 4  Description T6 à La grande-paroisse
#
#                                          description rooms surface    price  \
# 0  À Vendre - Maison avec fort potentiel sur 1 54...     4      92  139 750
# 1  Propriété de charme - Deux maisons + dépendanc...     5     132  139 750
# 2  Maison familiale 7 pièce(s) 150 m2 L'équipe l'...     7     150  520 000
# 3  Appartement très lumineux Au Mée sur Seine dan...     3      56  143 000
# 4  Maison individuelle À La Grande Paroisse belle...     6     110  275 000
#
#                     agency                  agencement  \
# 0         L'ADRESSE CHESSY  3 chambres,1 salle de bain
# 1         L'ADRESSE CHESSY   3 chambres,2 salles d'eau
# 2          L'ADRESSE ORSAY                  5 chambres
# 3  MEGAGENCE Vanessa MOLET                  2 chambres
# 4  MEGAGENCE Vanessa MOLET                  4 chambres
#
#                      general  annexes dependence     id_tech  \
# 0                        NaN     Cave   Terrasse  1764140340
# 1                        NaN     Cave        NaN  1764140340
# 2                        NaN      NaN   Terrasse  1764145200
# 3  Chauffage : collectif sol  Parking     Balcon  1763752440
# 4     Chauffage : individuel      NaN   Terrasse  1763752440
#
#                   reference
# 0  ParuVendu 14156758_1283B
# 1  ParuVendu 14156709_1284P
# 2   ParuVendu 14106019_1495
# 3     ParuVendu 193090_8920
# 4     ParuVendu 193089_8920

# %%
# Traitement des données pour ne récuperer que les colonnes nécessaires ( Groupement des annonces par Ville avec la sommme des chambres )
grouped_df = df.groupby('location').agg({
    'rooms': 'sum',
    'url': 'count'
}).rename(columns={'url': 'total_listings'}).reset_index()

# %%
from geopy.geocoders import Nominatim
import pandas as pd
import re, time, math

geolocator = Nominatim(user_agent="scraping_app", timeout=10)




# Fonction pour extraire les codes postaux entre parenthèses
def extract_postal_code(location):
    """
    Extracts a 5-digit postal code from a string, assuming it's in parentheses.
    Returns the postal code as a string, or None if not found.
    """
    if not location:
        return None
    match = re.search(r"\((\d{5})\)", location)
    if match:
        return match.group(1)
    return None


# Fonction de géocodage avec gestion des erreurs et délai
def geocode_location(location, i, total):
    try:
       
        formatted = extract_postal_code(location)
        print(f"[{i}/{total}] Géocodage : {formatted}")
        time.sleep(1)
        
        loc = geolocator.geocode({"postalcode": formatted, "country": "France"},exactly_one=True)
        if loc:
            return loc.latitude, loc.longitude
    except Exception:
        pass
    return math.nan, math.nan

total = len(grouped_df)

grouped_df[['latitude', 'longitude']] = [
    geocode_location(loc, i, total)
    for i, loc in enumerate(grouped_df['location'], start=1)
]
# Out:
# [1/556] Géocodage : 94480
# [2/556] Géocodage : 78260
# [3/556] Géocodage : 78113
# [4/556] Géocodage : 94140
# [5/556] Géocodage : 95580
# [6/556] Géocodage : 78570
# [7/556] Géocodage : 91670
# [8/556] Géocodage : 92160
# [9/556] Géocodage : 94110
# [10/556] Géocodage : 95100
# [11/556] Géocodage : 95400
# [12/556] Géocodage : 95400
# [13/556] Géocodage : 91290
# [14/556] Géocodage : 95810
# [15/556] Géocodage : 92600
# [16/556] Géocodage : 92600
# [17/556] Géocodage : 92600
# [18/556] Géocodage : 91200
# [19/556] Géocodage : 91200
# [20/556] Géocodage : 95570
# [21/556] Géocodage : 78410
# [22/556] Géocodage : 93300
# [23/556] Géocodage : 78930
# [24/556] Géocodage : 93600
# [25/556] Géocodage : 93600
# [26/556] Géocodage : 78770
# [27/556] Géocodage : 95430
# [28/556] Géocodage : 77210
# [29/556] Géocodage : 91630
# [30/556] Géocodage : 93170
# [31/556] Géocodage : 95560
# [32/556] Géocodage : 77700
# [33/556] Géocodage : 91160
# [34/556] Géocodage : 91610
# [35/556] Géocodage : 91610
# [36/556] Géocodage : 95260
# [37/556] Géocodage : 78270
# [38/556] Géocodage : 77320
# [39/556] Géocodage : 78650
# [40/556] Géocodage : 95870
# [41/556] Géocodage : 77940
# [42/556] Géocodage : 93000
# [43/556] Géocodage : 78390
# [44/556] Géocodage : 94470
# [45/556] Géocodage : 91790
# [46/556] Géocodage : 93140
# [47/556] Géocodage : 94380
# [48/556] Géocodage : 78270
# [49/556] Géocodage : 78270
# [50/556] Géocodage : 78410
# [51/556] Géocodage : 92100
# [52/556] Géocodage : 92100
# [53/556] Géocodage : 91850
# [54/556] Géocodage : 78113
# [55/556] Géocodage : 92340
# [56/556] Géocodage : 91800
# [57/556] Géocodage : 77620
# [58/556] Géocodage : 77480
# [59/556] Géocodage : 77480
# [60/556] Géocodage : 91220
# [61/556] Géocodage : 91220
# [62/556] Géocodage : 91650
# [63/556] Géocodage : 78980
# [64/556] Géocodage : 77170
# [65/556] Géocodage : 91640
# [66/556] Géocodage : 91800
# [67/556] Géocodage : 91680
# [68/556] Géocodage : 94360
# [69/556] Géocodage : 91220
# [70/556] Géocodage : 78830
# [71/556] Géocodage : 77600
# [72/556] Géocodage : 77600
# [73/556] Géocodage : 77130
# [74/556] Géocodage : 77130
# [75/556] Géocodage : 78420
# [76/556] Géocodage : 78955
# [77/556] Géocodage : 78420
# [78/556] Géocodage : 78955
# [79/556] Géocodage : 78420
# [80/556] Géocodage : 95000
# [81/556] Géocodage : 95800
# [82/556] Géocodage : 78720
# [83/556] Géocodage : 91590
# [84/556] Géocodage : 77240
# [85/556] Géocodage : 77144
# [86/556] Géocodage : 77430
# [87/556] Géocodage : 77430
# [88/556] Géocodage : 94500
# [89/556] Géocodage : 94500
# [90/556] Géocodage : 77420
# [91/556] Géocodage : 77420
# [92/556] Géocodage : 78570
# [93/556] Géocodage : 94220
# [94/556] Géocodage : 94220
# [95/556] Géocodage : 95750
# [96/556] Géocodage : 92290
# [97/556] Géocodage : 92290
# [98/556] Géocodage : 78400
# [99/556] Géocodage : 77390
# [100/556] Géocodage : 77390
# [101/556] Géocodage : 78450
# [102/556] Géocodage : 92370
# [103/556] Géocodage : 77500
# [104/556] Géocodage : 94430
# [105/556] Géocodage : 94430
# [106/556] Géocodage : 77160
# [107/556] Géocodage : 77700
# [108/556] Géocodage : 94550
# [109/556] Géocodage : 91380
# [110/556] Géocodage : 94600
# [111/556] Géocodage : 94600
# [112/556] Géocodage : 92290
# [113/556] Géocodage : 92140
# [114/556] Géocodage : 77410
# [115/556] Géocodage : 77410
# [116/556] Géocodage : 92110
# [117/556] Géocodage : 93390
# [118/556] Géocodage : 77090
# [119/556] Géocodage : 92700
# [120/556] Géocodage : 77380
# [121/556] Géocodage : 78113
# [122/556] Géocodage : 78700
# [123/556] Géocodage : 91100
# [124/556] Géocodage : 91100
# [125/556] Géocodage : 95240
# [126/556] Géocodage : 95240
# [127/556] Géocodage : 77170
# [128/556] Géocodage : 93470
# [129/556] Géocodage : 77120
# [130/556] Géocodage : 92400
# [131/556] Géocodage : 95800
# [132/556] Géocodage : 77181
# [133/556] Géocodage : 94000
# [134/556] Géocodage : 77840
# [135/556] Géocodage : 94000
# [136/556] Géocodage : 77230
# [137/556] Géocodage : 77140
# [138/556] Géocodage : 95330
# [139/556] Géocodage : 77520
# [140/556] Géocodage : 77520
# [141/556] Géocodage : 91410
# [142/556] Géocodage : 93700
# [143/556] Géocodage : 91210
# [144/556] Géocodage : 78440
# [145/556] Géocodage : 93440
# [146/556] Géocodage : 95600
# [147/556] Géocodage : 78920
# [148/556] Géocodage : 78990
# [149/556] Géocodage : 77184
# [150/556] Géocodage : 95880
# [151/556] Géocodage : 78680
# [152/556] Géocodage : 95610
# [153/556] Géocodage : 77450
# [154/556] Géocodage : 77940
# [155/556] Géocodage : 91150
# [156/556] Géocodage : 78810
# [157/556] Géocodage : 78410
# [158/556] Géocodage : 91690
# [159/556] Géocodage : 77300
# [160/556] Géocodage : 92260
# [161/556] Géocodage : 94120
# [162/556] Géocodage : 77610
# [163/556] Géocodage : 91640
# [164/556] Géocodage : 94120
# [165/556] Géocodage : 77610
# [166/556] Géocodage : 95130
# [167/556] Géocodage : 78840
# [168/556] Géocodage : 95740
# [169/556] Géocodage : 94260
# [170/556] Géocodage : 78950
# [171/556] Géocodage : 92380
# [172/556] Géocodage : 95140
# [173/556] Géocodage : 92230
# [174/556] Géocodage : 91190
# [175/556] Géocodage : 91190
# [176/556] Géocodage : 91720
# [177/556] Géocodage : 91400
# [178/556] Géocodage : 78270
# [179/556] Géocodage : 93460
# [180/556] Géocodage : 95190
# [181/556] Géocodage : 78930
# [182/556] Géocodage : 77400
# [183/556] Géocodage : 91350
# [184/556] Géocodage : 95810
# [185/556] Géocodage : 77166
# [186/556] Géocodage : 95410
# [187/556] Géocodage : 77580
# [188/556] Géocodage : 78930
# [189/556] Géocodage : 77390
# [190/556] Géocodage : 78280
# [191/556] Géocodage : 95220
# [192/556] Géocodage : 95220
# [193/556] Géocodage : 78550
# [194/556] Géocodage : 92130
# [195/556] Géocodage : 92130
# [196/556] Géocodage : 92130
# [197/556] Géocodage : 91760
# [198/556] Géocodage : 94200
# [199/556] Géocodage : 94200
# [200/556] Géocodage : 91640
# [201/556] Géocodage : 94340
# [202/556] Géocodage : 78760
# [203/556] Géocodage : 78350
# [204/556] Géocodage : 95280
# [205/556] Géocodage : 91260
# [206/556] Géocodage : 78820
# [207/556] Géocodage : 94240
# [208/556] Géocodage : 95290
# [209/556] Géocodage : 78620
# [210/556] Géocodage : 94240
# [211/556] Géocodage : 95290
# [212/556] Géocodage : 78170
# [213/556] Géocodage : 77720
# [214/556] Géocodage : 77720
# [215/556] Géocodage : 77370
# [216/556] Géocodage : 78410
# [217/556] Géocodage : 77260
# [218/556] Géocodage : 77260
# [219/556] Géocodage : 77320
# [220/556] Géocodage : 77260
# [221/556] Géocodage : 92250
# [222/556] Géocodage : 77130
# [223/556] Géocodage : 94510
# [224/556] Géocodage : 77000
# [225/556] Géocodage : 91620
# [226/556] Géocodage : 77400
# [227/556] Géocodage : 91510
# [228/556] Géocodage : 93150
# [229/556] Géocodage : 93350
# [230/556] Géocodage : 78150
# [231/556] Géocodage : 78150
# [232/556] Géocodage : 94270
# [233/556] Géocodage : 77350
# [234/556] Géocodage : 77350
# [235/556] Géocodage : 78230
# [236/556] Géocodage : 78610
# [237/556] Géocodage : 94170
# [238/556] Géocodage : 94170
# [239/556] Géocodage : 92350
# [240/556] Géocodage : 94420
# [241/556] Géocodage : 78560
# [242/556] Géocodage : 93310
# [243/556] Géocodage : 95500
# [244/556] Géocodage : 78340
# [245/556] Géocodage : 93260
# [246/556] Géocodage : 93320
# [247/556] Géocodage : 91940
# [248/556] Géocodage : 91310
# [249/556] Géocodage : 92300
# [250/556] Géocodage : 92300
# [251/556] Géocodage : 77127
# [252/556] Géocodage : 78520
# [253/556] Géocodage : 94450
# [254/556] Géocodage : 91470
# [255/556] Géocodage : 91310
# [256/556] Géocodage : 93190
# [257/556] Géocodage : 93190
# [258/556] Géocodage : 77440
# [259/556] Géocodage : 78270
# [260/556] Géocodage : 91160
# [261/556] Géocodage : 95450
# [262/556] Géocodage : 77650
# [263/556] Géocodage : 95380
# [264/556] Géocodage : 77540
# [265/556] Géocodage : 78200
# [266/556] Géocodage : 95420
# [267/556] Géocodage : 78114
# [268/556] Géocodage : 95420
# [269/556] Géocodage : 78114
# [270/556] Géocodage : 94700
# [271/556] Géocodage : 78600
# [272/556] Géocodage : 94700
# [273/556] Géocodage : 92240
# [274/556] Géocodage : 78200
# [275/556] Géocodage : 78711
# [276/556] Géocodage : 78200
# [277/556] Géocodage : 78711
# [278/556] Géocodage : 91460
# [279/556] Géocodage : 78750
# [280/556] Géocodage : 95640
# [281/556] Géocodage : 78160
# [282/556] Géocodage : 95670
# [283/556] Géocodage : 92430
# [284/556] Géocodage : 94440
# [285/556] Géocodage : 91300
# [286/556] Géocodage : 78580
# [287/556] Géocodage : 78310
# [288/556] Géocodage : 77100
# [289/556] Géocodage : 77000
# [290/556] Géocodage : 91540
# [291/556] Géocodage : 95810
# [292/556] Géocodage : 95180
# [293/556] Géocodage : 95540
# [294/556] Géocodage : 95540
# [295/556] Géocodage : 77410
# [296/556] Géocodage : 92190
# [297/556] Géocodage : 92360
# [298/556] Géocodage : 78250
# [299/556] Géocodage : 78970
# [300/556] Géocodage : 78970
# [301/556] Géocodage : 78250
# [302/556] Géocodage : 91490
# [303/556] Géocodage : 77290
# [304/556] Géocodage : 95570
# [305/556] Géocodage : 78840
# [306/556] Géocodage : 77550
# [307/556] Géocodage : 77550
# [308/556] Géocodage : 77570
# [309/556] Géocodage : 77320
# [310/556] Géocodage : 77130
# [311/556] Géocodage : 77130
# [312/556] Géocodage : 77144
# [313/556] Géocodage : 93370
# [314/556] Géocodage : 91230
# [315/556] Géocodage : 95370
# [316/556] Géocodage : 95370
# [317/556] Géocodage : 77690
# [318/556] Géocodage : 91310
# [319/556] Géocodage : 91310
# [320/556] Géocodage : 95160
# [321/556] Géocodage : 93100
# [322/556] Géocodage : 92120
# [323/556] Géocodage : 77450
# [324/556] Géocodage : 91420
# [325/556] Géocodage : 77250
# [326/556] Géocodage : 91150
# [327/556] Géocodage : 77720
# [328/556] Géocodage : 91390
# [329/556] Géocodage : 91390
# [330/556] Géocodage : 77120
# [331/556] Géocodage : 77480
# [332/556] Géocodage : 78670
# [333/556] Géocodage : 77370
# [334/556] Géocodage : 92000
# [335/556] Géocodage : 77100
# [336/556] Géocodage : 78640
# [337/556] Géocodage : 78640
# [338/556] Géocodage : 77140
# [339/556] Géocodage : 93360
# [340/556] Géocodage : 92200
# [341/556] Géocodage : 93330
# [342/556] Géocodage : 92200
# [343/556] Géocodage : 78410
# [344/556] Géocodage : 94130
# [345/556] Géocodage : 77186
# [346/556] Géocodage : 93160
# [347/556] Géocodage : 78590
# [348/556] Géocodage : 93130
# [349/556] Géocodage : 93160
# [350/556] Géocodage : 91620
# [351/556] Géocodage : 91340
# [352/556] Géocodage : 78125
# [353/556] Géocodage : 78910
# [354/556] Géocodage : 94310
# [355/556] Géocodage : 91400
# [356/556] Géocodage : 95520
# [357/556] Géocodage : 77280
# [358/556] Géocodage : 77330
# [359/556] Géocodage : 77330
# [360/556] Géocodage : 77330
# [361/556] Géocodage : 91120
# [362/556] Géocodage : 93500
# [363/556] Géocodage : 91550
# [364/556] Géocodage : 75010
# [365/556] Géocodage : 75011
# [366/556] Géocodage : 75012
# [367/556] Géocodage : 75013
# [368/556] Géocodage : 75014
# [369/556] Géocodage : 75015
# [370/556] Géocodage : 75016
# [371/556] Géocodage : 75017
# [372/556] Géocodage : 75018
# [373/556] Géocodage : 75019
# [374/556] Géocodage : 75002
# [375/556] Géocodage : 75020
# [376/556] Géocodage : 75003
# [377/556] Géocodage : 75004
# [378/556] Géocodage : 75005
# [379/556] Géocodage : 75006
# [380/556] Géocodage : 75007
# [381/556] Géocodage : 75008
# [382/556] Géocodage : 75009
# [383/556] Géocodage : 95620
# [384/556] Géocodage : 93380
# [385/556] Géocodage : 93380
# [386/556] Géocodage : 95480
# [387/556] Géocodage : 78370
# [388/556] Géocodage : 78125
# [389/556] Géocodage : 77470
# [390/556] Géocodage : 78300
# [391/556] Géocodage : 77515
# [392/556] Géocodage : 77340
# [393/556] Géocodage : 77135
# [394/556] Géocodage : 95000
# [395/556] Géocodage : 95300
# [396/556] Géocodage : 77410
# [397/556] Géocodage : 95590
# [398/556] Géocodage : 77160
# [399/556] Géocodage : 95380
# [400/556] Géocodage : 92800
# [401/556] Géocodage : 77720
# [402/556] Géocodage : 91480
# [403/556] Géocodage : 77860
# [404/556] Géocodage : 78120
# [405/556] Géocodage : 77510
# [406/556] Géocodage : 78550
# [407/556] Géocodage : 91130
# [408/556] Géocodage : 91130
# [409/556] Géocodage : 78150
# [410/556] Géocodage : 77680
# [411/556] Géocodage : 77680
# [412/556] Géocodage : 93230
# [413/556] Géocodage : 93110
# [414/556] Géocodage : 92500
# [415/556] Géocodage : 92500
# [416/556] Géocodage : 91530
# [417/556] Géocodage : 92210
# [418/556] Géocodage : 93200
# [419/556] Géocodage : 78100
# [420/556] Géocodage : 78112
# [421/556] Géocodage : 91250
# [422/556] Géocodage : 91180
# [423/556] Géocodage : 78610
# [424/556] Géocodage : 77230
# [425/556] Géocodage : 77630
# [426/556] Géocodage : 78520
# [427/556] Géocodage : 94100
# [428/556] Géocodage : 91240
# [429/556] Géocodage : 78860
# [430/556] Géocodage : 95310
# [431/556] Géocodage : 93400
# [432/556] Géocodage : 91280
# [433/556] Géocodage : 77165
# [434/556] Géocodage : 91770
# [435/556] Géocodage : 78730
# [436/556] Géocodage : 77320
# [437/556] Géocodage : 77160
# [438/556] Géocodage : 95350
# [439/556] Géocodage : 78210
# [440/556] Géocodage : 77750
# [441/556] Géocodage : 93200
# [442/556] Géocodage : 77310
# [443/556] Géocodage : 78100
# [444/556] Géocodage : 91180
# [445/556] Géocodage : 91250
# [446/556] Géocodage : 94160
# [447/556] Géocodage : 78520
# [448/556] Géocodage : 94100
# [449/556] Géocodage : 94100
# [450/556] Géocodage : 94210
# [451/556] Géocodage : 91240
# [452/556] Géocodage : 77178
# [453/556] Géocodage : 77140
# [454/556] Géocodage : 78470
# [455/556] Géocodage : 77400
# [456/556] Géocodage : 91700
# [457/556] Géocodage : 91700
# [458/556] Géocodage : 91250
# [459/556] Géocodage : 77210
# [460/556] Géocodage : 95110
# [461/556] Géocodage : 94440
# [462/556] Géocodage : 95200
# [463/556] Géocodage : 78500
# [464/556] Géocodage : 91160
# [465/556] Géocodage : 91600
# [466/556] Géocodage : 77176
# [467/556] Géocodage : 91600
# [468/556] Géocodage : 77730
# [469/556] Géocodage : 92330
# [470/556] Géocodage : 77700
# [471/556] Géocodage : 77170
# [472/556] Géocodage : 93270
# [473/556] Géocodage : 92310
# [474/556] Géocodage : 95230
# [475/556] Géocodage : 95230
# [476/556] Géocodage : 78120
# [477/556] Géocodage : 77460
# [478/556] Géocodage : 95390
# [479/556] Géocodage : 93240
# [480/556] Géocodage : 94370
# [481/556] Géocodage : 94370
# [482/556] Géocodage : 92150
# [483/556] Géocodage : 92310
# [484/556] Géocodage : 95150
# [485/556] Géocodage : 94320
# [486/556] Géocodage : 77400
# [487/556] Géocodage : 78117
# [488/556] Géocodage : 78190
# [489/556] Géocodage : 93290
# [490/556] Géocodage : 78510
# [491/556] Géocodage : 77470
# [492/556] Géocodage : 77360
# [493/556] Géocodage : 77830
# [494/556] Géocodage : 94460
# [495/556] Géocodage : 95760
# [496/556] Géocodage : 92170
# [497/556] Géocodage : 77910
# [498/556] Géocodage : 92420
# [499/556] Géocodage : 93410
# [500/556] Géocodage : 95490
# [501/556] Géocodage : 77000
# [502/556] Géocodage : 78140
# [503/556] Géocodage : 78480
# [504/556] Géocodage : 77670
# [505/556] Géocodage : 91370
# [506/556] Géocodage : 78000
# [507/556] Géocodage : 91810
# [508/556] Géocodage : 77240
# [509/556] Géocodage : 95510
# [510/556] Géocodage : 95270
# [511/556] Géocodage : 91270
# [512/556] Géocodage : 77130
# [513/556] Géocodage : 77250
# [514/556] Géocodage : 94440
# [515/556] Géocodage : 94800
# [516/556] Géocodage : 77710
# [517/556] Géocodage : 91360
# [518/556] Géocodage : 93250
# [519/556] Géocodage : 92390
# [520/556] Géocodage : 94290
# [521/556] Géocodage : 94190
# [522/556] Géocodage : 94190
# [523/556] Géocodage : 92390
# [524/556] Géocodage : 77174
# [525/556] Géocodage : 94290
# [526/556] Géocodage : 94190
# [527/556] Géocodage : 78670
# [528/556] Géocodage : 77124
# [529/556] Géocodage : 77270
# [530/556] Géocodage : 93420
# [531/556] Géocodage : 78450
# [532/556] Géocodage : 93430
# [533/556] Géocodage : 78930
# [534/556] Géocodage : 77410
# [535/556] Géocodage : 94350
# [536/556] Géocodage : 95400
# [537/556] Géocodage : 77560
# [538/556] Géocodage : 94350
# [539/556] Géocodage : 77520
# [540/556] Géocodage : 94300
# [541/556] Géocodage : 91170
# [542/556] Géocodage : 91170
# [543/556] Géocodage : 94400
# [544/556] Géocodage : 94400
# [545/556] Géocodage : 78960
# [546/556] Géocodage : 78960
# [547/556] Géocodage : 78140
# [548/556] Géocodage : 95470
# [549/556] Géocodage : 91330
# [550/556] Géocodage : 91520
# [551/556] Géocodage : 77620
# [552/556] Géocodage : 78680
# [553/556] Géocodage : 91450
# [554/556] Géocodage : 91580
# [555/556] Géocodage : 91000
# [556/556] Géocodage : 77166

# %%
# Sauvegarde du DataFrame géocodé
try: 
    grouped_df.to_csv("data/results_geocoded.csv", index=False) 
    print("Données géocodées sauvegardées dans data/results_geocoded.csv") 
except Exception as e: print(f"Erreur à l'enregistrement du fichier : {e}")
# Out:
# Données géocodées sauvegardées dans data/results_geocoded.csv

# %%
# Utilisation de Folium pour visualiser les données sur une carte
import folium
from IPython.display import display

try:
    df = pd.read_csv("data/results_geocoded.csv", dtype=str)
    # Initialiser la carte centrée sur la France
    map_center = [48.8499198, 2.6370411]  # Coordonnées approximatives du centre de la France
    folium_map = folium.Map(location=map_center, zoom_start=6)
    # Ajouter des marqueurs pour chaque ville
    for _, row in df.iterrows():
        if pd.notna(row['latitude']) and pd.notna(row['longitude']):
            folium.Marker(
                location=[float(row['latitude']), float(row['longitude'])],
                popup=f"{row['location']}: {row['total_listings']} annonces"
            ).add_to(folium_map)
    # Sauvegarder la carte dans un fichier HTML
    folium_map.save("data/map.html")
    display(folium_map)
    print("Carte sauvegardée dans data/map.html")
except Exception as e:
    print(f"Erreur lors de la création de la carte : {e}")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ac843372e4d2598c8081bb6520c67258 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ac843372e4d2598c8081bb6520c67258&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ac843372e4d2598c8081bb6520c67258 = L.map(
#                 &quot;map_ac843372e4d2598c8081bb6520c67258&quot;,
#                 {
#                     center: [48.8499198, 2.6370411],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bd47467a6dab2f0341485b8d1e46a4d6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_bd47467a6dab2f0341485b8d1e46a4d6.addTo(map_ac843372e4d2598c8081bb6520c67258);
#
#
#             var marker_7ac43c87b0b1e668e04d301f708e1889 = L.marker(
#                 [48.7236595, 2.4209566],
#                 {
# }
#             ).addTo(map_ac843372e4d2598c8081bb6520c67258);
#
#
#         var popup_652a4316a3239ad295e5248d9cbface3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_476442263a0187503b2d1fe7993af861 = $(`&lt;div id=&quot;html_476442263a0187503b2d1fe7993af861&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Ablon sur seine (94480): 2 annonces&lt;/div&gt;`)[0];
#                 popup_652a4316a3239ad295e5248d9cbface3.setContent(html_476442263a0187503b2d1fe7993af861);
#
#
#
#         marker_7ac43c87b0b1e668e04d301f708e1889.bindPopup(popup_652a4316a3239ad295e5248d9cbface3)
#         ;
#
#
#
#
#             var marker_324839e9631e9b4700be08f7bfe5bd4f = L.marker(
#                 [48.9676599, 2.0656028],
#                 {
# }
#             ).addTo(map_ac843372e4d2598c8081bb6520c67258);
#
#
#         var popup_7285133ce2b733828a9117dc57acc4ee = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b28ba9789b77ad66a409d3d9ea72068d = $(`&lt;div id=&quot;html_b28ba9789b77ad66a409d3d9ea72068d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Acheres (78260): 1 annonces&lt;/div&gt;`)[0];
#                 popup_7285133ce2b733828a9117dc57acc4ee.setContent(html_b28ba9789b77ad66a409d3d9ea72068d);
#
#
#
#         marker_324839e9631e9b4700be08f7bfe5bd4f.bindPopup(popup_7285133ce2b733828a9117dc57acc4ee)
#         ;
#
#
#
#
#             var marker_e25b92247d148d849860da32d6674126 = L.marker(
#                 [48.7294048, 1.6607875],
#                 {
# }
#             ).addTo(map_ac843372e4d2598c8081bb6520c67258);
#
#
#         var popup_0872dac2e87e66d63037ba1567e6e548 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3de3e20ec6a76146d8ff979c395e4f00 = $(`&lt;div id=&quot;html_3de3e20ec6a76146d8ff979c395e4f00&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Adainville (78113): 1 annonces&lt;/div&gt;`)[0];
#                 popup_0872dac2e87e66d63037ba1567e6e548.setContent(html_3de3e20ec6a76146d8ff979c395e4f00);
#
#
#
#         marker_e25b92247d148d849860da32d6674126.bindPopup(popup_0872dac2e87e66d63037ba1567e6e548)
#         ;
#
#
#
#
#             var marker_3f2d219b2569d25347ffc47a7c355ff3 = L.marker(
#                 [48.7968314, 2.4241141],
#                 {
# }
#             ).addTo(map_ac843372e4d2598c8081bb6520c67258);
#
#
#         var popup_80558d4450c8facbff090a408299f221 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8c64221cf782cec23a35fb3bb7878352 = $(`&lt;div id=&quot;html_8c64221cf782cec23a35fb3bb7878352&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Alfortville (94140): 10 annonces&lt;/div&gt;`)[0];
#                 popup_80558d4450c8facbff090a408299f221.setContent(html_8c64221cf782cec23a35fb3bb7878352);
#
#
#
#         marker_3f2d219b2569d25347ffc47a7c355ff3.bindPopup(popup_80558d4450c8facbff090a408299f221)
#         ;
#
#
#
#
#             var marker_d7827f1ea7fb143ffae1b2095cd0a43c = L.marker(
#                 [49.0098323, 2.3038114],
#                 {
# }
#             ).addTo(map_ac843372e4d2598c8081bb6520c67258);
#
#
#         var popup_0758bd2842c8f1593ffc0764e5690d8e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_df3e4879be15667e1bbeb7143020a20f = $(`&lt;div id=&quot;html_df3e4879be15667e1bbeb7143020a20f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Andilly (95580): 1 annonces&lt;/div&gt;`)[0];
#                 popup_0758bd2842c8f1593ffc0764e5690d8e
# Carte sauvegardée dans data/map.html
