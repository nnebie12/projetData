# %%
import pandas as pd
import math

column_names = [
    "url",          # 0: https://...
    "title",        # 1: Vente Maison...
    "location",     # 2: Bray sur seine...
    "desc_short",   # 3: Description T4...
    "description",  # 4: À Vendre...
    "rooms",        # 5: 4
    "surface",      # 6: 92
    "price",        # 7: 139 750
    "agency",       # 8: L'ADRESSE CHESSY
    "agencement",   # 9: 3 chambres, 1 salle de bain
    "general",    # 10: (vide dans ton exemple)
    "annexes",      # 11: Cave
    "dependence",      # 12: Terrasse
    "id_tech",      # 13: 1764140340
    "reference"     # 14: ParuVendu...
]

# On charge tout en 'string' (dtype=str) pour éviter les erreurs de conversion au début
try:
    df = pd.read_csv(
        "data/results.csv",
        header=None,
        names=column_names,
        dtype=str,
        on_bad_lines='skip' # Si une ligne est mal formée, on la saute au lieu de planter
    )
except Exception as e:
    print(f"Erreur à l'ouverture du fichier : {e}")
    df = pd.DataFrame()

df.head()  # Affiche les premières lignes du DataFrame pour vérification²
# Out:
#                                                  url  \
# 0  https://www.paruvendu.fr/immobilier/vente/mais...
# 1  https://www.paruvendu.fr/immobilier/vente/mais...
# 2  https://www.paruvendu.fr/immobilier/vente/mais...
# 3  https://www.paruvendu.fr/immobilier/vente/appa...
# 4  https://www.paruvendu.fr/immobilier/vente/mais...
#
#                               title                    location  \
# 0       Vente Maison 4 pièces 92 m²      Bray sur seine (77480)
# 1      Vente Maison 5 pièces 132 m²             Provins (77160)
# 2      Vente Maison 7 pièces 150 m²               Orsay (91400)
# 3  Vente Appartement 3 pièces 56 m²    Le mee-sur-seine (77350)
# 4      Vente Maison 6 pièces 110 m²  La grande-paroisse (77130)
#
#                             desc_short  \
# 0      Description T4 à Bray sur seine
# 1             Description T5 à Provins
# 2               Description T7 à Orsay
# 3    Description T3 à Le mee-sur-seine
# 4  Description T6 à La grande-paroisse
#
#                                          description rooms surface    price  \
# 0  À Vendre - Maison avec fort potentiel sur 1 54...     4      92  139 750
# 1  Propriété de charme - Deux maisons + dépendanc...     5     132  139 750
# 2  Maison familiale 7 pièce(s) 150 m2 L'équipe l'...     7     150  520 000
# 3  Appartement très lumineux Au Mée sur Seine dan...     3      56  143 000
# 4  Maison individuelle À La Grande Paroisse belle...     6     110  275 000
#
#                     agency                  agencement  \
# 0         L'ADRESSE CHESSY  3 chambres,1 salle de bain
# 1         L'ADRESSE CHESSY   3 chambres,2 salles d'eau
# 2          L'ADRESSE ORSAY                  5 chambres
# 3  MEGAGENCE Vanessa MOLET                  2 chambres
# 4  MEGAGENCE Vanessa MOLET                  4 chambres
#
#                      general  annexes dependence     id_tech  \
# 0                        NaN     Cave   Terrasse  1764140340
# 1                        NaN     Cave        NaN  1764140340
# 2                        NaN      NaN   Terrasse  1764145200
# 3  Chauffage : collectif sol  Parking     Balcon  1763752440
# 4     Chauffage : individuel      NaN   Terrasse  1763752440
#
#                   reference
# 0  ParuVendu 14156758_1283B
# 1  ParuVendu 14156709_1284P
# 2   ParuVendu 14106019_1495
# 3     ParuVendu 193090_8920
# 4     ParuVendu 193089_8920

# %%
# Traitement des données pour ne récuperer que les colonnes nécessaires ( Groupement des annonces par Ville avec la sommme des chambres )
grouped_df = df.groupby('location').agg({
    'rooms': 'sum',
    'url': 'count'
}).rename(columns={'url': 'total_listings'}).reset_index()

# %%
from geopy.geocoders import Nominatim
import pandas as pd
import re, time, math

geolocator = Nominatim(user_agent="scraping_app", timeout=10)

# Fonction pour enlever les codes postaux entre parenthèses
def remove_postal_code(location):
    if not location:
        return location
    return re.sub(r"\s*\(\d{5}\)", "", location).strip()

# Fonction de géocodage avec gestion des erreurs et délai
def geocode_location(location, i, total):
    try:
        formatted = remove_postal_code(location)
        print(f"[{i}/{total}] Géocodage : {formatted}")
        time.sleep(1)
        loc = geolocator.geocode(formatted,exactly_one=True)
        if loc:
            return loc.latitude, loc.longitude
    except Exception:
        pass
    return math.nan, math.nan

total = len(grouped_df)

grouped_df[['latitude', 'longitude']] = [
    geocode_location(loc, i, total)
    for i, loc in enumerate(grouped_df['location'], start=1)
]
# Out:
# [1/556] Géocodage : Ablon sur seine
# [2/556] Géocodage : Acheres
# [3/556] Géocodage : Adainville
# [4/556] Géocodage : Alfortville
# [5/556] Géocodage : Andilly
# [6/556] Géocodage : Andrésy
# [7/556] Géocodage : Angerville
# [8/556] Géocodage : Antony
# [9/556] Géocodage : Arcueil
# [10/556] Géocodage : Argenteuil
# [11/556] Géocodage : Arnouville
# [12/556] Géocodage : Arnouville les gonesse
# [13/556] Géocodage : Arpajon
# [14/556] Géocodage : Arronville
# [15/556] Géocodage : Asnieres sur seine
# [16/556] Géocodage : Asnieres-sur-seine
# [17/556] Géocodage : Asnières-sur-seine
# [18/556] Géocodage : Athis mons
# [19/556] Géocodage : Athis-mons
# [20/556] Géocodage : Attainville
# [21/556] Géocodage : Aubergenville
# [22/556] Géocodage : Aubervilliers
# [23/556] Géocodage : Auffreville brasseuil
# [24/556] Géocodage : Aulnay sous bois
# [25/556] Géocodage : Aulnay-sous-bois
# [26/556] Géocodage : Auteuil
# [27/556] Géocodage : Auvers-sur-oise
# [28/556] Géocodage : Avon
# [29/556] Géocodage : Avrainville
# [30/556] Géocodage : Bagnolet
# [31/556] Géocodage : Baillet en france
# [32/556] Géocodage : Bailly-romainvilliers
# [33/556] Géocodage : Ballainvilliers
# [34/556] Géocodage : Ballancourt sur essonne
# [35/556] Géocodage : Ballancourt- sur-essonne
# [36/556] Géocodage : Beaumont sur oise
# [37/556] Géocodage : Bennecourt
# [38/556] Géocodage : Beton-bazoches
# [39/556] Géocodage : Beynes
# [40/556] Géocodage : Bezons
# [41/556] Géocodage : Blennes
# [42/556] Géocodage : Bobigny
# [43/556] Géocodage : Bois-d'arcy
# [44/556] Géocodage : Boissy saint leger
# [45/556] Géocodage : Boissy-sous-saint-yon
# [46/556] Géocodage : Bondy
# [47/556] Géocodage : Bonneuil-sur-marne
# [48/556] Géocodage : Bonnieres sur seine
# [49/556] Géocodage : Bonnières-sur-seine
# [50/556] Géocodage : Bouafle
# [51/556] Géocodage : Boulogne billancourt
# [52/556] Géocodage : Boulogne-billancourt
# [53/556] Géocodage : Bouray sur juine
# [54/556] Géocodage : Bourdonne
# [55/556] Géocodage : Bourg-la-reine
# [56/556] Géocodage : Boussy saint antoine
# [57/556] Géocodage : Bransles
# [58/556] Géocodage : Bray sur seine
# [59/556] Géocodage : Bray-sur-seine
# [60/556] Géocodage : Bretigny sur orge
# [61/556] Géocodage : Bretigny-sur-orge
# [62/556] Géocodage : Breuillet
# [63/556] Géocodage : Breval
# [64/556] Géocodage : Brie-comte-robert
# [65/556] Géocodage : Briis sous forges
# [66/556] Géocodage : Brunoy
# [67/556] Géocodage : Bruyères-le-châtel
# [68/556] Géocodage : Bry-sur-marne
# [69/556] Géocodage : Brétigny-sur-orge
# [70/556] Géocodage : Bullion
# [71/556] Géocodage : Bussy saint georges
# [72/556] Géocodage : Bussy-saint-georges
# [73/556] Géocodage : Cannes ecluse
# [74/556] Géocodage : Cannes-Écluse
# [75/556] Géocodage : Carrieres sur seine
# [76/556] Géocodage : Carrieres-sous-poissy
# [77/556] Géocodage : Carrieres-sur-seine
# [78/556] Géocodage : Carrières-sous-poissy
# [79/556] Géocodage : Carrières-sur-seine
# [80/556] Géocodage : Cergy
# [81/556] Géocodage : Cergy
# [82/556] Géocodage : Cernay-la-ville
# [83/556] Géocodage : Cerny
# [84/556] Géocodage : Cesson
# [85/556] Géocodage : Chalifert
# [86/556] Géocodage : Champagne sur seine
# [87/556] Géocodage : Champagne-sur-seine
# [88/556] Géocodage : Champigny sur marne
# [89/556] Géocodage : Champigny-sur-marne
# [90/556] Géocodage : Champs sur marne
# [91/556] Géocodage : Champs-sur-marne
# [92/556] Géocodage : Chanteloup-les-vignes
# [93/556] Géocodage : Charenton le pont
# [94/556] Géocodage : Charenton-le-pont
# [95/556] Géocodage : Chars
# [96/556] Géocodage : Chatenay malabry
# [97/556] Géocodage : Chatenay-malabry
# [98/556] Géocodage : Chatou
# [99/556] Géocodage : Chaumes en brie
# [100/556] Géocodage : Chaumes-en-brie
# [101/556] Géocodage : Chavenay
# [102/556] Géocodage : Chaville
# [103/556] Géocodage : Chelles
# [104/556] Géocodage : Chennevieres sur marne
# [105/556] Géocodage : ChenneviÈres-sur-marne
# [106/556] Géocodage : Chenoise
# [107/556] Géocodage : Chessy
# [108/556] Géocodage : Chevilly-larue
# [109/556] Géocodage : Chilly-mazarin
# [110/556] Géocodage : Choisy le roi
# [111/556] Géocodage : Choisy-le-roi
# [112/556] Géocodage : Châtenay-malabry
# [113/556] Géocodage : Clamart
# [114/556] Géocodage : Claye souilly
# [115/556] Géocodage : Claye-souilly
# [116/556] Géocodage : Clichy
# [117/556] Géocodage : Clichy-sous-bois
# [118/556] Géocodage : Collegien
# [119/556] Géocodage : Colombes
# [120/556] Géocodage : Combs-la-ville
# [121/556] Géocodage : Condé-sur-vesgre
# [122/556] Géocodage : Conflans-sainte-honorine
# [123/556] Géocodage : Corbeil essonnes
# [124/556] Géocodage : Corbeil-essonnes
# [125/556] Géocodage : Cormeilles en parisis
# [126/556] Géocodage : Cormeilles-en-parisis
# [127/556] Géocodage : Coubert
# [128/556] Géocodage : Coubron
# [129/556] Géocodage : Coulommiers
# [130/556] Géocodage : Courbevoie
# [131/556] Géocodage : Courdimanche
# [132/556] Géocodage : Courtry
# [133/556] Géocodage : Creteil
# [134/556] Géocodage : Crouy-sur-ourcq
# [135/556] Géocodage : Créteil
# [136/556] Géocodage : Dammartin en goele
# [137/556] Géocodage : Darvault
# [138/556] Géocodage : Domont
# [139/556] Géocodage : Donnemarie dontilly
# [140/556] Géocodage : Donnemarie-dontilly
# [141/556] Géocodage : Dourdan
# [142/556] Géocodage : Drancy
# [143/556] Géocodage : Draveil
# [144/556] Géocodage : Drocourt
# [145/556] Géocodage : Dugny
# [146/556] Géocodage : Eaubonne
# [147/556] Géocodage : Ecquevilly
# [148/556] Géocodage : Elancourt
# [149/556] Géocodage : Emerainville
# [150/556] Géocodage : Enghien-les-bains
# [151/556] Géocodage : Epone
# [152/556] Géocodage : Eragny
# [153/556] Géocodage : Esbly
# [154/556] Géocodage : Esmans
# [155/556] Géocodage : Etampes
# [156/556] Géocodage : Feucherolles
# [157/556] Géocodage : Flins sur seine
# [158/556] Géocodage : Fontaine la riviere
# [159/556] Géocodage : Fontainebleau
# [160/556] Géocodage : Fontenay aux roses
# [161/556] Géocodage : Fontenay sous bois
# [162/556] Géocodage : Fontenay tresigny
# [163/556] Géocodage : Fontenay-les-briis
# [164/556] Géocodage : Fontenay-sous-bois
# [165/556] Géocodage : Fontenay-trésigny
# [166/556] Géocodage : Franconville
# [167/556] Géocodage : Freneuse
# [168/556] Géocodage : Frepillon
# [169/556] Géocodage : Fresnes
# [170/556] Géocodage : Gambais
# [171/556] Géocodage : Garches
# [172/556] Géocodage : Garges les gonesse
# [173/556] Géocodage : Gennevilliers
# [174/556] Géocodage : Gif sur yvette
# [175/556] Géocodage : Gif-sur-yvette
# [176/556] Géocodage : Gironville-sur-essonne
# [177/556] Géocodage : Gometz la ville
# [178/556] Géocodage : Gommecourt
# [179/556] Géocodage : Gournay-sur-marne
# [180/556] Géocodage : Goussainville
# [181/556] Géocodage : Goussonville
# [182/556] Géocodage : Gouvernes
# [183/556] Géocodage : Grigny
# [184/556] Géocodage : Grisy les platres
# [185/556] Géocodage : Grisy-suisnes
# [186/556] Géocodage : Groslay
# [187/556] Géocodage : Guerard
# [188/556] Géocodage : Guerville
# [189/556] Géocodage : Guignes
# [190/556] Géocodage : Guyancourt
# [191/556] Géocodage : Herblay sur seine
# [192/556] Géocodage : Herblay-sur-seine
# [193/556] Géocodage : Houdan
# [194/556] Géocodage : Issy les moulineaux
# [195/556] Géocodage : Issy-les-moulineaux
# [196/556] Géocodage : Issy-les-moulineaux (h...
# [197/556] Géocodage : Itteville
# [198/556] Géocodage : Ivry sur seine
# [199/556] Géocodage : Ivry-sur-seine
# [200/556] Géocodage : Janvry
# [201/556] Géocodage : Joinville le pont
# [202/556] Géocodage : Jouars-pontchartrain
# [203/556] Géocodage : Jouy en josas
# [204/556] Géocodage : Jouy-le-moutier
# [205/556] Géocodage : Juvisy sur orge
# [206/556] Géocodage : Juziers
# [207/556] Géocodage : L hay les roses
# [208/556] Géocodage : L isle adam
# [209/556] Géocodage : L' etang-la-ville
# [210/556] Géocodage : L'haÿ-les-roses
# [211/556] Géocodage : L'isle adam
# [212/556] Géocodage : La celle saint cloud
# [213/556] Géocodage : La chapelle gauthier
# [214/556] Géocodage : La chapelle-gauthier
# [215/556] Géocodage : La croix en brie
# [216/556] Géocodage : La falaise
# [217/556] Géocodage : La ferte sous jouarre
# [218/556] Géocodage : La ferte-sous-jouarre
# [219/556] Géocodage : La ferté-gaucher
# [220/556] Géocodage : La ferté-sous-jouarre
# [221/556] Géocodage : La garenne colombes
# [222/556] Géocodage : La grande-paroisse
# [223/556] Géocodage : La queue-en-brie
# [224/556] Géocodage : La rochette
# [225/556] Géocodage : La ville-du-bois
# [226/556] Géocodage : Lagny-sur-marne
# [227/556] Géocodage : Lardy
# [228/556] Géocodage : Le blanc mesnil
# [229/556] Géocodage : Le bourget
# [230/556] Géocodage : Le chesnay
# [231/556] Géocodage : Le chesnay rocquencourt
# [232/556] Géocodage : Le kremlin bicetre
# [233/556] Géocodage : Le mee-sur-seine
# [234/556] Géocodage : Le mée-sur-seine
# [235/556] Géocodage : Le pecq
# [236/556] Géocodage : Le perray-en-yvelines
# [237/556] Géocodage : Le perreux sur marne
# [238/556] Géocodage : Le perreux-sur-marne
# [239/556] Géocodage : Le plessis robinson
# [240/556] Géocodage : Le plessis-trévise
# [241/556] Géocodage : Le port-marly
# [242/556] Géocodage : Le pre-saint-gervais
# [243/556] Géocodage : Le thillay
# [244/556] Géocodage : Les clayes sous bois
# [245/556] Géocodage : Les lilas
# [246/556] Géocodage : Les pavillons sous bois
# [247/556] Géocodage : Les ulis
# [248/556] Géocodage : Leuville-sur-orge
# [249/556] Géocodage : Levallois perret
# [250/556] Géocodage : Levallois-perret
# [251/556] Géocodage : Lieusaint
# [252/556] Géocodage : Limay
# [253/556] Géocodage : Limeil brevannes
# [254/556] Géocodage : Limours
# [255/556] Géocodage : Linas
# [256/556] Géocodage : Livry gargan
# [257/556] Géocodage : Livry-gargan
# [258/556] Géocodage : Lizy sur ourcq
# [259/556] Géocodage : Lommoye
# [260/556] Géocodage : Longjumeau
# [261/556] Géocodage : Longuesse
# [262/556] Géocodage : Longueville
# [263/556] Géocodage : Louvres
# [264/556] Géocodage : Lumigny nesles ormeaux
# [265/556] Géocodage : Magnanville
# [266/556] Géocodage : Magny en vexin
# [267/556] Géocodage : Magny les hameaux
# [268/556] Géocodage : Magny-en-vexin
# [269/556] Géocodage : Magny-les-hameaux
# [270/556] Géocodage : Maisons alfort
# [271/556] Géocodage : Maisons laffitte
# [272/556] Géocodage : Maisons-alfort
# [273/556] Géocodage : Malakoff
# [274/556] Géocodage : Mantes la jolie
# [275/556] Géocodage : Mantes la ville
# [276/556] Géocodage : Mantes-la-jolie
# [277/556] Géocodage : Mantes-la-ville
# [278/556] Géocodage : Marcoussis
# [279/556] Géocodage : Mareil marly
# [280/556] Géocodage : Marines
# [281/556] Géocodage : Marly le roi
# [282/556] Géocodage : Marly-la-ville
# [283/556] Géocodage : Marnes la coquette
# [284/556] Géocodage : Marolles-en-brie
# [285/556] Géocodage : Massy
# [286/556] Géocodage : Maule
# [287/556] Géocodage : Maurepas
# [288/556] Géocodage : Meaux
# [289/556] Géocodage : Melun
# [290/556] Géocodage : Mennecy
# [291/556] Géocodage : Menouville
# [292/556] Géocodage : Menucourt
# [293/556] Géocodage : Mery sur oise
# [294/556] Géocodage : Mery-sur-oise
# [295/556] Géocodage : Messy
# [296/556] Géocodage : Meudon
# [297/556] Géocodage : Meudon la foret
# [298/556] Géocodage : Meulan en yvelines
# [299/556] Géocodage : Mezieres sur seine
# [300/556] Géocodage : Mezieres-sur-seine
# [301/556] Géocodage : Mezy-sur-seine
# [302/556] Géocodage : Milly-la-forêt
# [303/556] Géocodage : Mitry-mory
# [304/556] Géocodage : Moisselles
# [305/556] Géocodage : Moisson
# [306/556] Géocodage : Moissy cramayel
# [307/556] Géocodage : Moissy-cramayel
# [308/556] Géocodage : Mondreville
# [309/556] Géocodage : Montdauphin
# [310/556] Géocodage : Montereau fault yonne
# [311/556] Géocodage : Montereau-fault-yonne
# [312/556] Géocodage : Montevrain
# [313/556] Géocodage : Montfermeil
# [314/556] Géocodage : Montgeron
# [315/556] Géocodage : Montigny les cormeilles
# [316/556] Géocodage : Montigny-lès-cormeilles
# [317/556] Géocodage : Montigny-sur-loing
# [318/556] Géocodage : Montlhery
# [319/556] Géocodage : Montlhéry
# [320/556] Géocodage : Montmorency
# [321/556] Géocodage : Montreuil
# [322/556] Géocodage : Montrouge
# [323/556] Géocodage : Montry
# [324/556] Géocodage : Morangis
# [325/556] Géocodage : Moret-loing-et-orvanne
# [326/556] Géocodage : Morigny champigny
# [327/556] Géocodage : Mormant
# [328/556] Géocodage : Morsang sur orge
# [329/556] Géocodage : Morsang-sur-orge
# [330/556] Géocodage : Mouroux
# [331/556] Géocodage : Mousseaux-lès-bray
# [332/556] Géocodage : Médan
# [333/556] Géocodage : Nangis
# [334/556] Géocodage : Nanterre
# [335/556] Géocodage : Nanteuil les meaux
# [336/556] Géocodage : Neauphle le chateau
# [337/556] Géocodage : Neauphle-le-château
# [338/556] Géocodage : Nemours
# [339/556] Géocodage : Neuilly plaisance
# [340/556] Géocodage : Neuilly sur seine
# [341/556] Géocodage : Neuilly-sur-marne
# [342/556] Géocodage : Neuilly-sur-seine
# [343/556] Géocodage : Nezel
# [344/556] Géocodage : Nogent-sur-marne
# [345/556] Géocodage : Noisiel
# [346/556] Géocodage : Noisy le grand
# [347/556] Géocodage : Noisy le roi
# [348/556] Géocodage : Noisy le sec
# [349/556] Géocodage : Noisy-le-grand
# [350/556] Géocodage : Nozay
# [351/556] Géocodage : Ollainville
# [352/556] Géocodage : Orcemont
# [353/556] Géocodage : Orgerus
# [354/556] Géocodage : Orly
# [355/556] Géocodage : Orsay
# [356/556] Géocodage : Osny
# [357/556] Géocodage : Othis
# [358/556] Géocodage : Ozoir la ferriere
# [359/556] Géocodage : Ozoir-la-ferriere
# [360/556] Géocodage : Ozoir-la-ferrière
# [361/556] Géocodage : Palaiseau
# [362/556] Géocodage : Pantin
# [363/556] Géocodage : Paray-vieille-poste
# [364/556] Géocodage : Paris 10
# [365/556] Géocodage : Paris 11
# [366/556] Géocodage : Paris 12
# [367/556] Géocodage : Paris 13
# [368/556] Géocodage : Paris 14
# [369/556] Géocodage : Paris 15
# [370/556] Géocodage : Paris 16
# [371/556] Géocodage : Paris 17
# [372/556] Géocodage : Paris 18
# [373/556] Géocodage : Paris 19
# [374/556] Géocodage : Paris 2
# [375/556] Géocodage : Paris 20
# [376/556] Géocodage : Paris 3
# [377/556] Géocodage : Paris 4
# [378/556] Géocodage : Paris 5
# [379/556] Géocodage : Paris 6
# [380/556] Géocodage : Paris 7
# [381/556] Géocodage : Paris 8
# [382/556] Géocodage : Paris 9
# [383/556] Géocodage : Parmain
# [384/556] Géocodage : Pierrefitte sur seine
# [385/556] Géocodage : Pierrefitte-sur-seine
# [386/556] Géocodage : Pierrelaye
# [387/556] Géocodage : Plaisir
# [388/556] Géocodage : Poigny la foret
# [389/556] Géocodage : Poincy
# [390/556] Géocodage : Poissy
# [391/556] Géocodage : Pommeuse
# [392/556] Géocodage : Pontault combault
# [393/556] Géocodage : Pontcarre
# [394/556] Géocodage : Pontoise
# [395/556] Géocodage : Pontoise
# [396/556] Géocodage : Precy-sur-marne
# [397/556] Géocodage : Presles
# [398/556] Géocodage : Provins
# [399/556] Géocodage : Puiseux en france
# [400/556] Géocodage : Puteaux
# [401/556] Géocodage : Quiers
# [402/556] Géocodage : Quincy-sous-sénart
# [403/556] Géocodage : Quincy-voisins
# [404/556] Géocodage : Rambouillet
# [405/556] Géocodage : Rebais
# [406/556] Géocodage : Richebourg
# [407/556] Géocodage : Ris orangis
# [408/556] Géocodage : Ris-orangis
# [409/556] Géocodage : Rocquencourt
# [410/556] Géocodage : Roissy en brie
# [411/556] Géocodage : Roissy-en-brie
# [412/556] Géocodage : Romainville
# [413/556] Géocodage : Rosny sous bois
# [414/556] Géocodage : Rueil malmaison
# [415/556] Géocodage : Rueil-malmaison
# [416/556] Géocodage : Saint cheron
# [417/556] Géocodage : Saint cloud
# [418/556] Géocodage : Saint denis
# [419/556] Géocodage : Saint germain en laye
# [420/556] Géocodage : Saint germain en laye
# [421/556] Géocodage : Saint germain les corbeil
# [422/556] Géocodage : Saint germain lès arpajon
# [423/556] Géocodage : Saint leger en yvelines
# [424/556] Géocodage : Saint mard
# [425/556] Géocodage : Saint martin en biere
# [426/556] Géocodage : Saint martin la garenne
# [427/556] Géocodage : Saint maur des fosses
# [428/556] Géocodage : Saint michel sur orge
# [429/556] Géocodage : Saint nom la breteche
# [430/556] Géocodage : Saint ouen l aumone
# [431/556] Géocodage : Saint ouen sur seine
# [432/556] Géocodage : Saint pierre du perray
# [433/556] Géocodage : Saint soupplets
# [434/556] Géocodage : Saint vrain
# [435/556] Géocodage : Saint-arnoult-en-yvelines
# [436/556] Géocodage : Saint-barthélemy
# [437/556] Géocodage : Saint-brice
# [438/556] Géocodage : Saint-brice-sous-forêt
# [439/556] Géocodage : Saint-cyr-l'ecole
# [440/556] Géocodage : Saint-cyr-sur-morin
# [441/556] Géocodage : Saint-denis
# [442/556] Géocodage : Saint-fargeau-ponthierry
# [443/556] Géocodage : Saint-germain-en-laye
# [444/556] Géocodage : Saint-germain-lès-arpajon
# [445/556] Géocodage : Saint-germain-lès-corbeil
# [446/556] Géocodage : Saint-mandé
# [447/556] Géocodage : Saint-martin-la-garenne
# [448/556] Géocodage : Saint-maur-des-fossÉs
# [449/556] Géocodage : Saint-maur-des-fossés
# [450/556] Géocodage : Saint-maur-des-fossés
# [451/556] Géocodage : Saint-michel-sur-orge
# [452/556] Géocodage : Saint-pathus
# [453/556] Géocodage : Saint-pierre-lès-nemours
# [454/556] Géocodage : Saint-remy-les-chevreuse
# [455/556] Géocodage : Saint-thibault-des-vignes
# [456/556] Géocodage : Sainte genevieve des bois
# [457/556] Géocodage : Sainte-geneviève-des-bois
# [458/556] Géocodage : Saintry sur seine
# [459/556] Géocodage : Samoreau
# [460/556] Géocodage : Sannois
# [461/556] Géocodage : Santeny
# [462/556] Géocodage : Sarcelles
# [463/556] Géocodage : Sartrouville
# [464/556] Géocodage : Saulx-les-chartreux
# [465/556] Géocodage : Savigny sur orge
# [466/556] Géocodage : Savigny-le-temple
# [467/556] Géocodage : Savigny-sur-orge
# [468/556] Géocodage : Saâcy-sur-marne
# [469/556] Géocodage : Sceaux
# [470/556] Géocodage : Serris
# [471/556] Géocodage : Servon
# [472/556] Géocodage : Sevran
# [473/556] Géocodage : Sevres
# [474/556] Géocodage : Soisy sous montmorency
# [475/556] Géocodage : Soisy-sous-montmorency
# [476/556] Géocodage : Sonchamp
# [477/556] Géocodage : Souppes-sur-loing
# [478/556] Géocodage : St prix
# [479/556] Géocodage : Stains
# [480/556] Géocodage : Sucy en brie
# [481/556] Géocodage : Sucy-en-brie
# [482/556] Géocodage : Suresnes
# [483/556] Géocodage : Sèvres
# [484/556] Géocodage : Taverny
# [485/556] Géocodage : Thiais
# [486/556] Géocodage : Thorigny-sur-marne
# [487/556] Géocodage : Toussus-le-noble
# [488/556] Géocodage : Trappes
# [489/556] Géocodage : Tremblay-en-france
# [490/556] Géocodage : Triel sur seine
# [491/556] Géocodage : Trilport
# [492/556] Géocodage : Vaires sur marne
# [493/556] Géocodage : Valence-en-brie
# [494/556] Géocodage : Valenton
# [495/556] Géocodage : Valmondois
# [496/556] Géocodage : Vanves
# [497/556] Géocodage : Varreddes
# [498/556] Géocodage : Vaucresson
# [499/556] Géocodage : Vaujours
# [500/556] Géocodage : Vaureal
# [501/556] Géocodage : Vaux le penil
# [502/556] Géocodage : Velizy villacoublay
# [503/556] Géocodage : Verneuil-sur-seine
# [504/556] Géocodage : Vernou la celle sur seine
# [505/556] Géocodage : Verrières-le-buisson
# [506/556] Géocodage : Versailles
# [507/556] Géocodage : Vert le grand
# [508/556] Géocodage : Vert saint denis
# [509/556] Géocodage : Vetheuil
# [510/556] Géocodage : Viarmes
# [511/556] Géocodage : Vigneux sur seine
# [512/556] Géocodage : Ville-saint-jacques
# [513/556] Géocodage : Villecerf
# [514/556] Géocodage : Villecresnes
# [515/556] Géocodage : Villejuif
# [516/556] Géocodage : Villemaréchal
# [517/556] Géocodage : Villemoisson-sur-orge
# [518/556] Géocodage : Villemomble
# [519/556] Géocodage : Villeneuve la garenne
# [520/556] Géocodage : Villeneuve le roi
# [521/556] Géocodage : Villeneuve saint georges
# [522/556] Géocodage : Villeneuve st georges
# [523/556] Géocodage : Villeneuve-la-garenne
# [524/556] Géocodage : Villeneuve-le-comte
# [525/556] Géocodage : Villeneuve-le-roi
# [526/556] Géocodage : Villeneuve-saint-georges
# [527/556] Géocodage : Villennes-sur-seine
# [528/556] Géocodage : Villenoy
# [529/556] Géocodage : Villeparisis
# [530/556] Géocodage : Villepinte
# [531/556] Géocodage : Villepreux
# [532/556] Géocodage : Villetaneuse
# [533/556] Géocodage : Villette
# [534/556] Géocodage : Villevaude
# [535/556] Géocodage : Villiers sur marne
# [536/556] Géocodage : Villiers-le-bel
# [537/556] Géocodage : Villiers-saint-georges
# [538/556] Géocodage : Villiers-sur-marne
# [539/556] Géocodage : Vimpelles
# [540/556] Géocodage : Vincennes
# [541/556] Géocodage : Viry chatillon
# [542/556] Géocodage : Viry-chatillon
# [543/556] Géocodage : Vitry sur seine
# [544/556] Géocodage : Vitry-sur-seine
# [545/556] Géocodage : Voisins le bretonneux
# [546/556] Géocodage : Voisins-le-bretonneux
# [547/556] Géocodage : Vélizy-villacoublay
# [548/556] Géocodage : Vémars
# [549/556] Géocodage : Yerres
# [550/556] Géocodage : Égly
# [551/556] Géocodage : Égreville
# [552/556] Géocodage : Épône
# [553/556] Géocodage : Étiolles
# [554/556] Géocodage : Étréchy
# [555/556] Géocodage : Évry
# [556/556] Géocodage : Évry-grégy-sur-yerre

# %%
# Sauvegarde du DataFrame géocodé
try: 
    grouped_df.to_csv("data/results_geocoded.csv", index=False) 
    print("Données géocodées sauvegardées dans data/results_geocoded.csv") 
except Exception as e: print(f"Erreur à l'enregistrement du fichier : {e}")
# Out:
# Données géocodées sauvegardées dans data/results_geocoded.csv

# %%
# Utilisation de Folium pour visualiser les données sur une carte
import folium
from IPython.display import display

try:
    df = pd.read_csv("data/results_geocoded.csv", dtype=str)
    # Initialiser la carte centrée sur la France
    map_center = [48.8499198, 2.6370411]  # Coordonnées approximatives du centre de la France
    folium_map = folium.Map(location=map_center, zoom_start=6)
    # Ajouter des marqueurs pour chaque ville
    for _, row in df.iterrows():
        if pd.notna(row['latitude']) and pd.notna(row['longitude']):
            folium.Marker(
                location=[float(row['latitude']), float(row['longitude'])],
                popup=f"{row['location']}: {row['total_listings']} annonces"
            ).add_to(folium_map)
    # Sauvegarder la carte dans un fichier HTML
    folium_map.save("data/map.html")
    display(folium_map)
    print("Carte sauvegardée dans data/map.html")
except Exception as e:
    print(f"Erreur lors de la création de la carte : {e}")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5be8147e4f8b951ae76300264cd9ec03 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5be8147e4f8b951ae76300264cd9ec03&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5be8147e4f8b951ae76300264cd9ec03 = L.map(
#                 &quot;map_5be8147e4f8b951ae76300264cd9ec03&quot;,
#                 {
#                     center: [48.8499198, 2.6370411],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_17878e2a0ae8d024d3fe958300c3592a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_17878e2a0ae8d024d3fe958300c3592a.addTo(map_5be8147e4f8b951ae76300264cd9ec03);
#
#
#             var marker_79021d5c7c29a1e5e5dee5f4b622fd74 = L.marker(
#                 [48.7247785, 2.4216096],
#                 {
# }
#             ).addTo(map_5be8147e4f8b951ae76300264cd9ec03);
#
#
#         var popup_a41676c151107547f872634b95d260ca = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5aaaf483c91c4516b1c7889ed780edd6 = $(`&lt;div id=&quot;html_5aaaf483c91c4516b1c7889ed780edd6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Ablon sur seine (94480): 2 annonces&lt;/div&gt;`)[0];
#                 popup_a41676c151107547f872634b95d260ca.setContent(html_5aaaf483c91c4516b1c7889ed780edd6);
#
#
#
#         marker_79021d5c7c29a1e5e5dee5f4b622fd74.bindPopup(popup_a41676c151107547f872634b95d260ca)
#         ;
#
#
#
#
#             var marker_f19080f73bd8dcc18d719dcd7f84b4e4 = L.marker(
#                 [47.2774561, 2.4491821],
#                 {
# }
#             ).addTo(map_5be8147e4f8b951ae76300264cd9ec03);
#
#
#         var popup_5b548e4ba0e8706090b9d3e8b5cf5781 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e2c454bd3bb07f528aa89b6c455ac671 = $(`&lt;div id=&quot;html_e2c454bd3bb07f528aa89b6c455ac671&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Acheres (78260): 1 annonces&lt;/div&gt;`)[0];
#                 popup_5b548e4ba0e8706090b9d3e8b5cf5781.setContent(html_e2c454bd3bb07f528aa89b6c455ac671);
#
#
#
#         marker_f19080f73bd8dcc18d719dcd7f84b4e4.bindPopup(popup_5b548e4ba0e8706090b9d3e8b5cf5781)
#         ;
#
#
#
#
#             var marker_00fd1d5274ff7628bf453441c8955ec5 = L.marker(
#                 [48.7223394, 1.6514132],
#                 {
# }
#             ).addTo(map_5be8147e4f8b951ae76300264cd9ec03);
#
#
#         var popup_45f230829cf19716d5b1f03972352d46 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8c597b281fa5b8cc7ffb0fb745c9fb64 = $(`&lt;div id=&quot;html_8c597b281fa5b8cc7ffb0fb745c9fb64&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Adainville (78113): 1 annonces&lt;/div&gt;`)[0];
#                 popup_45f230829cf19716d5b1f03972352d46.setContent(html_8c597b281fa5b8cc7ffb0fb745c9fb64);
#
#
#
#         marker_00fd1d5274ff7628bf453441c8955ec5.bindPopup(popup_45f230829cf19716d5b1f03972352d46)
#         ;
#
#
#
#
#             var marker_75cd064a18b196fce3881f9b581a4385 = L.marker(
#                 [48.8051624, 2.4197113],
#                 {
# }
#             ).addTo(map_5be8147e4f8b951ae76300264cd9ec03);
#
#
#         var popup_08a20ca9929bfe248ef828258fd0d7ec = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_75734d2890f0ecaf9fe3bda3f143994a = $(`&lt;div id=&quot;html_75734d2890f0ecaf9fe3bda3f143994a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Alfortville (94140): 10 annonces&lt;/div&gt;`)[0];
#                 popup_08a20ca9929bfe248ef828258fd0d7ec.setContent(html_75734d2890f0ecaf9fe3bda3f143994a);
#
#
#
#         marker_75cd064a18b196fce3881f9b581a4385.bindPopup(popup_08a20ca9929bfe248ef828258fd0d7ec)
#         ;
#
#
#
#
#             var marker_af2f1b443f6cb73bea911a32e08bbfb7 = L.marker(
#                 [48.7662318, 5.881351],
#                 {
# }
#             ).addTo(map_5be8147e4f8b951ae76300264cd9ec03);
#
#
#         var popup_91c1c2a4f7a39a4be7e9d0dc5ac5040b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1597e22d38e5f69437469416051e0973 = $(`&lt;div id=&quot;html_1597e22d38e5f69437469416051e0973&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Andilly (95580): 1 annonces&lt;/div&gt;`)[0];
#                 popup_91c1c2a4f7a39a4be7e9d0dc5ac5040b.
# Carte sauvegardée dans data/map.html
